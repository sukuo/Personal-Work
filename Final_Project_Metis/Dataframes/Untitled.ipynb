# %%
import pandas as pd

# %%
pd.read_csv('prod_df.csv')
# Out:
#       Unnamed: 0            Airline Name        Airports  \
# 0              0  American Airlines Inc.  ('ABQ', 'DFW')
# 1              1  American Airlines Inc.  ('ALB', 'CLT')
# 2              2  American Airlines Inc.  ('ANC', 'DFW')
# 3              3  American Airlines Inc.  ('ANC', 'LAX')
# 4              4  American Airlines Inc.  ('ANC', 'PHX')
# 5              5  American Airlines Inc.  ('ATL', 'CLT')
# 6              6  American Airlines Inc.  ('ATL', 'DFW')
# 7              7  American Airlines Inc.  ('ATL', 'LAX')
# 8              8  American Airlines Inc.  ('ATL', 'LAX')
# 9              9  American Airlines Inc.  ('ATL', 'LAX')
# 10            10  American Airlines Inc.  ('ATL', 'LAX')
# 11            11  American Airlines Inc.  ('ATL', 'LAX')
# 12            12  American Airlines Inc.  ('ATL', 'LAX')
# 13            13  American Airlines Inc.  ('ATL', 'LAX')
# 14            14  American Airlines Inc.  ('ATL', 'LAX')
# ...
